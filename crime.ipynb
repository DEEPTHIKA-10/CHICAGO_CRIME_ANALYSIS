# %%
pip install pandas
# Out:
# ...
#   Using cached pandas-2.2.3-cp313-cp313-win_amd64.whl.metadata (19 kB)
# ...
# Using cached pandas-2.2.3-cp313-cp313-win_amd64.whl (11.5 MB)
# ...
#    ---------------------------------------- 0.0/12.6 MB ? eta -:--:--
#    -- ------------------------------------- 0.8/12.6 MB 8.0 MB/s eta 0:00:02
#    --------- ------------------------------ 2.9/12.6 MB 8.2 MB/s eta 0:00:02
#    --------------- ------------------------ 5.0/12.6 MB 8.9 MB/s eta 0:00:01
#    ------------------- -------------------- 6.0/12.6 MB 8.4 MB/s eta 0:00:01
#    --------------------- ------------------ 6.8/12.6 MB 7.4 MB/s eta 0:00:01
#    ------------------------ --------------- 7.6/12.6 MB 6.7 MB/s eta 0:00:01
#    -------------------------- ------------- 8.4/12.6 MB 6.1 MB/s eta 0:00:01
#    ----------------------------- ---------- 9.2/12.6 MB 5.6 MB/s eta 0:00:01
#    ------------------------------ --------- 9.7/12.6 MB 5.3 MB/s eta 0:00:01
#    -------------------------------- ------- 10.2/12.6 MB 5.1 MB/s eta 0:00:01
# ...

# %%
pip install openpyxl
# Out:
# ...
#   Using cached openpyxl-3.1.5-py2.py3-none-any.whl.metadata (2.5 kB)
# ...
#   Using cached et_xmlfile-2.0.0-py3-none-any.whl.metadata (2.7 kB)
# Using cached openpyxl-3.1.5-py2.py3-none-any.whl (250 kB)
# Using cached et_xmlfile-2.0.0-py3-none-any.whl (18 kB)
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 24.3.1 -> 25.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
pip install mysql-connector-python
# Out:
# ...
#
#   Using cached mysql_connector_python-9.2.0-cp313-cp313-win_amd64.whl.metadata (6.2 kB)
# Using cached mysql_connector_python-9.2.0-cp313-cp313-win_amd64.whl (16.1 MB)
# ...
# [notice] A new release of pip is available: 24.3.1 -> 25.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import pandas as pd
import numpy as np
import mysql.connector

# %%
df=pd.read_csv(r"C:\Users\kumar\Desktop\chicago_project\output_file.csv")
df
# Out:
#               ID Case Number                 Date                      Block  \
# 0        5741943    HN549294  2007-08-25 09:22:18         074XX N ROGERS AVE
# 1          25953    JE240540  2021-05-24 15:06:00        020XX N LARAMIE AVE
# 2          26038    JE279849  2021-06-26 09:24:00      062XX N MC CORMICK RD
# 3       13279676    JG507211  2023-11-09 07:30:00           019XX W BYRON ST
# 4       13274752    JG501049  2023-11-12 07:59:00  086XX S COTTAGE GROVE AVE
# ...          ...         ...                  ...                        ...
# 549994   1715153     G516233  2001-08-27 23:00:00       036XX S LAKE PARK AV
# 549995   1799889     G625392  2001-10-16 16:30:00         065XX S STEWART AV
# 549996   1769834     G583569  2001-09-29 05:35:00    031XX N CENTRAL PARK AV
# 549997   1788327     G610965  2001-09-12 09:05:00          065XX S CICERO AV
# 549998   1810693     G627247  2001-10-18 17:34:00       053XX W FERDINAND ST
#
#         IUCR         Primary Type  \
# ...

# %%
block_latitude_dict = {}

for index, row in df.iterrows():
    block = row['Block']
    latitude = row['Latitude']
    if block not in block_latitude_dict and pd.isnull(latitude)==False:
        block_latitude_dict[block] = latitude

for index, row in df.iterrows():
    block = row['Block']
    latitude = row['Latitude']
    if pd.isnull(latitude) and block in block_latitude_dict:
        df.at[index, 'Latitude'] = block_latitude_dict[block]

df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 549999 entries, 0 to 549998
# Data columns (total 22 columns):
#  #   Column                Non-Null Count   Dtype
# ---  ------                --------------   -----
#  0   ID                    549999 non-null  int64
#  1   Case Number           549999 non-null  object
#  2   Date                  549999 non-null  object
#  3   Block                 549999 non-null  object
#  4   IUCR                  549999 non-null  object
#  5   Primary Type          549999 non-null  object
#  6   Description           549999 non-null  object
#  7   Location Description  548326 non-null  object
#  8   Arrest                549999 non-null  bool
#  9   Domestic              549999 non-null  bool
#  10  Beat                  549999 non-null  int64
#  11  District              549999 non-null  int64
#  12  Ward                  213674 non-null  float64
#  13  Community Area        215093 non-null  float64
# ...

# %%
block_longitude_dict = {}

for index, row in df.iterrows():
    block = row['Block']
    longitude = row['Longitude']
    if block not in block_longitude_dict and pd.isnull(longitude)==False:
        block_longitude_dict[block] = longitude

for index, row in df.iterrows():
    block = row['Block']
    longitude = row['Longitude']
    if pd.isnull(longitude) and block in block_longitude_dict:
        df.at[index, 'Longitude'] = block_longitude_dict[block]

df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 549999 entries, 0 to 549998
# Data columns (total 22 columns):
#  #   Column                Non-Null Count   Dtype
# ---  ------                --------------   -----
#  0   ID                    549999 non-null  int64
#  1   Case Number           549999 non-null  object
#  2   Date                  549999 non-null  object
#  3   Block                 549999 non-null  object
#  4   IUCR                  549999 non-null  object
#  5   Primary Type          549999 non-null  object
#  6   Description           549999 non-null  object
#  7   Location Description  548326 non-null  object
#  8   Arrest                549999 non-null  bool
#  9   Domestic              549999 non-null  bool
#  10  Beat                  549999 non-null  int64
#  11  District              549999 non-null  int64
#  12  Ward                  213674 non-null  float64
#  13  Community Area        215093 non-null  float64
# ...

# %%
block_location_dict = {}

for index, row in df.iterrows():
    block = row['Block']
    location = row['Location']
    if block not in block_location_dict and pd.isnull(location)==False:
        block_location_dict[block] = location

for index, row in df.iterrows():
    block = row['Block']
    location = row['Location']
    if pd.isnull(location) and block in block_location_dict:
        df.at[index, 'Location'] = block_location_dict[block]

df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 549999 entries, 0 to 549998
# Data columns (total 22 columns):
#  #   Column                Non-Null Count   Dtype
# ---  ------                --------------   -----
#  0   ID                    549999 non-null  int64
#  1   Case Number           549999 non-null  object
#  2   Date                  549999 non-null  object
#  3   Block                 549999 non-null  object
#  4   IUCR                  549999 non-null  object
#  5   Primary Type          549999 non-null  object
#  6   Description           549999 non-null  object
#  7   Location Description  548326 non-null  object
#  8   Arrest                549999 non-null  bool
#  9   Domestic              549999 non-null  bool
#  10  Beat                  549999 non-null  int64
#  11  District              549999 non-null  int64
#  12  Ward                  213674 non-null  float64
#  13  Community Area        215093 non-null  float64
# ...

# %%
block_X_coordinate_dict = {}

for index, row in df.iterrows():
    block = row['Block']
    X_coordinate = row['X Coordinate']
    if block not in block_X_coordinate_dict and pd.isnull(X_coordinate)==False:
        block_X_coordinate_dict[block] = X_coordinate

for index, row in df.iterrows():
    block = row['Block']
    X_coordinate = row['X Coordinate']
    if pd.isnull(X_coordinate) and block in block_X_coordinate_dict:
        df.at[index, 'X Coordinate'] = block_X_coordinate_dict[block]

df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 549999 entries, 0 to 549998
# Data columns (total 22 columns):
#  #   Column                Non-Null Count   Dtype
# ---  ------                --------------   -----
#  0   ID                    549999 non-null  int64
#  1   Case Number           549999 non-null  object
#  2   Date                  549999 non-null  object
#  3   Block                 549999 non-null  object
#  4   IUCR                  549999 non-null  object
#  5   Primary Type          549999 non-null  object
#  6   Description           549999 non-null  object
#  7   Location Description  548326 non-null  object
#  8   Arrest                549999 non-null  bool
#  9   Domestic              549999 non-null  bool
#  10  Beat                  549999 non-null  int64
#  11  District              549999 non-null  int64
#  12  Ward                  213674 non-null  float64
#  13  Community Area        215093 non-null  float64
# ...

# %%
block_Y_coordinate_dict = {}

for index, row in df.iterrows():
    block = row['Block']
    Y_coordinate = row['Y Coordinate']
    if block not in block_Y_coordinate_dict and pd.isnull(Y_coordinate)==False:
        block_Y_coordinate_dict[block] = Y_coordinate

for index, row in df.iterrows():
    block = row['Block']
    Y_coordinate = row['Y Coordinate']
    if pd.isnull(Y_coordinate) and block in block_Y_coordinate_dict:
        df.at[index, 'Y Coordinate'] = block_Y_coordinate_dict[block]

df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 549999 entries, 0 to 549998
# Data columns (total 22 columns):
#  #   Column                Non-Null Count   Dtype
# ---  ------                --------------   -----
#  0   ID                    549999 non-null  int64
#  1   Case Number           549999 non-null  object
#  2   Date                  549999 non-null  object
#  3   Block                 549999 non-null  object
#  4   IUCR                  549999 non-null  object
#  5   Primary Type          549999 non-null  object
#  6   Description           549999 non-null  object
#  7   Location Description  548326 non-null  object
#  8   Arrest                549999 non-null  bool
#  9   Domestic              549999 non-null  bool
#  10  Beat                  549999 non-null  int64
#  11  District              549999 non-null  int64
#  12  Ward                  213674 non-null  float64
#  13  Community Area        215093 non-null  float64
# ...

# %%
df = df[~df['Latitude'].isnull()]
df = df.drop(columns=['Ward', 'Community Area'])

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 548522 entries, 0 to 549998
# Data columns (total 20 columns):
#  #   Column                Non-Null Count   Dtype
# ---  ------                --------------   -----
#  0   ID                    548522 non-null  int64
#  1   Case Number           548522 non-null  object
#  2   Date                  548522 non-null  object
#  3   Block                 548522 non-null  object
#  4   IUCR                  548522 non-null  object
#  5   Primary Type          548522 non-null  object
#  6   Description           548522 non-null  object
#  7   Location Description  546899 non-null  object
#  8   Arrest                548522 non-null  bool
#  9   Domestic              548522 non-null  bool
#  10  Beat                  548522 non-null  int64
#  11  District              548522 non-null  int64
#  12  FBI Code              548522 non-null  object
#  13  X Coordinate          548522 non-null  float64
# ...

# %%
df['Date'] = pd.to_datetime(df['Date'], errors='coerce')  # Convert to datetime
df['Week'] = df['Date'].dt.isocalendar().week  # Extract week number

# %%
# Extract Hour
df['CrimeHour'] = df['Date'].dt.hour

# %%
df.shape
# Out:
# (548522, 22)

# %%
df.isna().sum
# Out:
# <bound method DataFrame.sum of            ID  Case Number   Date  Block   IUCR  Primary Type  Description  \
# 0       False        False  False  False  False         False        False
# 1       False        False  False  False  False         False        False
# 2       False        False  False  False  False         False        False
# 3       False        False  False  False  False         False        False
# 4       False        False  False  False  False         False        False
# ...       ...          ...    ...    ...    ...           ...          ...
# 549994  False        False  False  False  False         False        False
# 549995  False        False  False  False  False         False        False
# 549996  False        False  False  False  False         False        False
# 549997  False        False  False  False  False         False        False
# 549998  False        False  False  False  False         False        False
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 548522 entries, 0 to 549998
# Data columns (total 22 columns):
#  #   Column                Non-Null Count   Dtype
# ---  ------                --------------   -----
#  0   ID                    548522 non-null  int64
#  1   Case Number           548522 non-null  object
#  2   Date                  548522 non-null  datetime64[ns]
#  3   Block                 548522 non-null  object
#  4   IUCR                  548522 non-null  object
#  5   Primary Type          548522 non-null  object
#  6   Description           548522 non-null  object
#  7   Location Description  546899 non-null  object
#  8   Arrest                548522 non-null  bool
#  9   Domestic              548522 non-null  bool
#  10  Beat                  548522 non-null  int64
#  11  District              548522 non-null  int64
#  12  FBI Code              548522 non-null  object
#  13  X Coordinate          548522 non-null  float64
# ...

# %%
df.drop_duplicates(inplace=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 548522 entries, 0 to 549998
# Data columns (total 22 columns):
#  #   Column                Non-Null Count   Dtype
# ---  ------                --------------   -----
#  0   ID                    548522 non-null  int64
#  1   Case Number           548522 non-null  object
#  2   Date                  548522 non-null  datetime64[ns]
#  3   Block                 548522 non-null  object
#  4   IUCR                  548522 non-null  object
#  5   Primary Type          548522 non-null  object
#  6   Description           548522 non-null  object
#  7   Location Description  546899 non-null  object
#  8   Arrest                548522 non-null  bool
#  9   Domestic              548522 non-null  bool
#  10  Beat                  548522 non-null  int64
#  11  District              548522 non-null  int64
#  12  FBI Code              548522 non-null  object
#  13  X Coordinate          548522 non-null  float64
# ...

# %%
import calendar
df['Leap Year'] = df['Year'].apply(lambda x: 'Yes' if calendar.isleap(int(x)) else 'No')

# %%
df['Primary Type'] = df['Primary Type'].replace(['DOMESTIC VIOLENCE','CONCEALED CARRY LICENSE VIOLATION','LIQUOR LAW VIOLATION','PUBLIC PEACE VIOLATION','WEAPONS VIOLATION'],'VIOLATIONS')
df['Location Description'] = df['Location Description'].replace(['LAUNDRY ROOM','POOLROOM','ROOF','COACH HOUSE','SEWER','NESSTAND','POOL ROOM','FOREST PRESERVE','YARD'], 'OTHER')

# %%
df.isnull().sum
# Out:
# <bound method DataFrame.sum of            ID  Case Number   Date  Block   IUCR  Primary Type  Description  \
# 0       False        False  False  False  False         False        False
# 1       False        False  False  False  False         False        False
# 2       False        False  False  False  False         False        False
# 3       False        False  False  False  False         False        False
# 4       False        False  False  False  False         False        False
# ...       ...          ...    ...    ...    ...           ...          ...
# 549994  False        False  False  False  False         False        False
# 549995  False        False  False  False  False         False        False
# 549996  False        False  False  False  False         False        False
# 549997  False        False  False  False  False         False        False
# 549998  False        False  False  False  False         False        False
#
# ...

# %%
df.shape
# Out:
# (548522, 23)

# %%
# Create 'Month' column
df['Month'] = df['Date'].dt.month

# Create 'Day' column
df['Day'] = df['Date'].dt.day

# %%
df=df.drop_duplicates()
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 541984 entries, 1 to 549998
# Data columns (total 25 columns):
#  #   Column                Non-Null Count   Dtype
# ---  ------                --------------   -----
#  0   ID                    541984 non-null  int64
#  1   Case Number           541984 non-null  object
#  2   Date                  541984 non-null  datetime64[ns]
#  3   Block                 541984 non-null  object
#  4   IUCR                  541984 non-null  object
#  5   Primary Type          541984 non-null  object
#  6   Description           541984 non-null  object
#  7   Location Description  541984 non-null  object
#  8   Arrest                541984 non-null  bool
#  9   Domestic              541984 non-null  bool
#  10  Beat                  541984 non-null  int64
#  11  District              541984 non-null  int64
#  12  FBI Code              541984 non-null  object
#  13  X Coordinate          541984 non-null  float64
# ...

# %%
df['Updated On'] = pd.to_datetime(df['Updated On'], errors='coerce')

# %%
df=df.dropna()
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 541984 entries, 1 to 549998
# Data columns (total 25 columns):
#  #   Column                Non-Null Count   Dtype
# ---  ------                --------------   -----
#  0   ID                    541984 non-null  int64
#  1   Case Number           541984 non-null  object
#  2   Date                  541984 non-null  datetime64[ns]
#  3   Block                 541984 non-null  object
#  4   IUCR                  541984 non-null  object
#  5   Primary Type          541984 non-null  object
#  6   Description           541984 non-null  object
#  7   Location Description  541984 non-null  object
#  8   Arrest                541984 non-null  bool
#  9   Domestic              541984 non-null  bool
#  10  Beat                  541984 non-null  int64
#  11  District              541984 non-null  int64
#  12  FBI Code              541984 non-null  object
#  13  X Coordinate          541984 non-null  float64
# ...

# %%
# Save the cleaned and processed DataFrame to a new CSV file
output_path = r"C:/Users/kumar/Desktop/chicago_project/chicago/cleaned_output_file.csv"
df.to_csv(output_path, index=False)

print(f"File saved successfully to {output_path}")
# Out:
# File saved successfully to C:/Users/kumar/Desktop/chicago_project/chicago/cleaned_output_file.csv

# %% [markdown]
# CREATING MySQL DATABASE

# %%
import mysql.connector
from mysql.connector import Error

def connect_to_local_mysql():
    try:
        connection = mysql.connector.connect(
            host="localhost",      
            user="root",  
            password="", 
            database="chicago_crime",  
            port=3306              
        )
        
        if connection.is_connected():
            print("Connected to MySQL database!")
            
            cursor = connection.cursor()
            cursor.execute("SELECT DATABASE();")
            database_name = cursor.fetchone()
            print(f"You're connected to database: {database_name[0]}")
            
            #cursor.close()
            #connection.close()
            #print("MySQL connection closed.")
    except Error as e:
        print(f"Error: {e}")
        
connect_to_local_mysql()
# Out:
# Connected to MySQL database!
# You're connected to database: chicago_crime

# %%
#sql connection
conn=mysql.connector.connect(host="localhost", user="root", password="",database="chicago_crime")
my_cursor = conn.cursor()
my_cursor.execute("CREATE DATABASE IF NOT EXISTS chicago_crime")

# %%
df.shape
# Out:
# (541984, 25)

# %%
df.columns
# Out:
# Index(['ID', 'Case Number', 'Date', 'Block', 'IUCR', 'Primary Type',
#        'Description', 'Location Description', 'Arrest', 'Domestic', 'Beat',
#        'District', 'FBI Code', 'X Coordinate', 'Y Coordinate', 'Year',
#        'Updated On', 'Latitude', 'Longitude', 'Location', 'Week', 'CrimeHour',
#        'Leap Year', 'Month', 'Day'],
#       dtype='object')

# %%
my_cursor.execute("""
    CREATE TABLE IF NOT EXISTS crime_data (
        ID INT PRIMARY KEY,
        CaseNumber VARCHAR(255) NOT NULL,
        CrimeDate DATETIME,  -- Changed DATE to DATETIME to include time
        Block VARCHAR(255) NOT NULL,
        IUCR VARCHAR(255) NOT NULL,
        PrimaryType VARCHAR(255) NOT NULL,
        Description VARCHAR(255) NOT NULL,
        LocationDescription VARCHAR(255) NOT NULL,
        Arrest TINYINT(1) NOT NULL,
        Domestic TINYINT(1) NOT NULL,
        Beat INT NOT NULL,
        District INT NOT NULL,
        FBICode VARCHAR(255) NOT NULL,
        XCoordinate FLOAT NOT NULL,
        YCoordinate FLOAT NOT NULL,
        CrimeYear INT NOT NULL,
        UpdatedOn DATETIME NOT NULL, -- Changed DATE to DATETIME
        Latitude FLOAT NOT NULL,
        Longitude FLOAT NOT NULL,
        Location VARCHAR(255) NOT NULL,
        Week INT NOT NULL,  
        CrimeHour INT NOT NULL, 
        LeapYear TINYINT(1),  -- **Added missing comma**
        Month INT NOT NULL,
        Day INT NOT NULL
    )
""")

print("MySQL Table Created in chicago_crime Database Successfully!")
# Out:
# MySQL Table Created in chicago_crime Database Successfully!

# %%
my_cursor.execute("TRUNCATE TABLE crime_data")

# %%
print("Data preview before inserting:")
print(df.head())  # Show first few rows
print("Total rows:", len(df))
# Out:
# Data preview before inserting:
#          ID Case Number                Date                      Block  IUCR  \
# 1     25953    JE240540 2021-05-24 15:06:00        020XX N LARAMIE AVE   110
# 2     26038    JE279849 2021-06-26 09:24:00      062XX N MC CORMICK RD   110
# 3  13279676    JG507211 2023-11-09 07:30:00           019XX W BYRON ST   620
# 4  13274752    JG501049 2023-11-12 07:59:00  086XX S COTTAGE GROVE AVE   454
# 6  13203321    JG415333 2023-09-06 17:00:00           002XX N Wells st  1320
#
#       Primary Type                                        Description  \
# 1         HOMICIDE                                FIRST DEGREE MURDER
# 2         HOMICIDE                                FIRST DEGREE MURDER
# 3         BURGLARY                                     UNLAWFUL ENTRY
# 4          BATTERY  AGGRAVATED P.O. - HANDS, FISTS, FEET, NO / MIN...
# 6  CRIMINAL DAMAGE                                         TO VEHICLE
#
# ...

# %%
df
# Out:
#               ID Case Number                 Date                      Block  \
# 0          25953    JE240540  2021-05-24 15:06:00        020XX N LARAMIE AVE
# 1          26038    JE279849  2021-06-26 09:24:00      062XX N MC CORMICK RD
# 2       13279676    JG507211  2023-11-09 07:30:00           019XX W BYRON ST
# 3       13274752    JG501049  2023-11-12 07:59:00  086XX S COTTAGE GROVE AVE
# 4       13203321    JG415333  2023-09-06 17:00:00           002XX N Wells st
# ...          ...         ...                  ...                        ...
# 541979   1715153     G516233  2001-08-27 23:00:00       036XX S LAKE PARK AV
# 541980   1799889     G625392  2001-10-16 16:30:00         065XX S STEWART AV
# 541981   1769834     G583569  2001-09-29 05:35:00    031XX N CENTRAL PARK AV
# 541982   1788327     G610965  2001-09-12 09:05:00          065XX S CICERO AV
# 541983   1810693     G627247  2001-10-18 17:34:00       053XX W FERDINAND ST
#
#         IUCR         Primary Type  \
# ...

# %%
df.columns
# Out:
# Index(['ID', 'Case Number', 'Date', 'Block', 'IUCR', 'Primary Type',
#        'Description', 'Location Description', 'Arrest', 'Domestic', 'Beat',
#        'District', 'FBI Code', 'X Coordinate', 'Y Coordinate', 'Year',
#        'Updated On', 'Latitude', 'Longitude', 'Location', 'Week', 'CrimeHour',
#        'Leap Year', 'Month', 'Day'],
#       dtype='object')

# %%
import mysql.connector
import pandas as pd

# Connect to the database
conn = mysql.connector.connect(
    host="localhost",
    user="root",
    password="",
    database="chicago_crime"
)
my_cursor = conn.cursor()

# Define the corrected SQL insert query
insert_query = """
    INSERT INTO crime_data
    (ID, CaseNumber, CrimeDate, Block, IUCR, PrimaryType, Description, LocationDescription,
    Arrest, Domestic, Beat, District, FBICode, XCoordinate, YCoordinate,
    CrimeYear, UpdatedOn, Latitude, Longitude, Location, Week, LeapYear, Month, Day,CrimeHour)
    VALUES (%s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s)
"""

# Load data (ensure column names match your SQL table)
df = pd.read_csv("C:/Users/kumar/Desktop/chicago_project/chicago/cleaned_output_file.csv")  # Replace with your actual data source

# Convert DataFrame rows into tuples and insert them
for index, row in df.iterrows():
    try:
        my_cursor.execute(insert_query, tuple(row))
    except mysql.connector.Error as err:
        print(f"Error inserting row {index+1}: {err}")

# Commit transaction
conn.commit()

print("Data inserted successfully into MySQL database.")

# Close connection
my_cursor.close()
conn.close()
# Out:
# Data inserted successfully into MySQL database.
